# %% [markdown]
# # python programming
# ## python programming
# ### python programming
# #### python programming
# ##### python programming

# %% [markdown]
# 1. a
# 2. b
# 3. c
#   1. d
#   2. e
#   3. f

# %% [markdown]
# [google] (https://sites.google.com/view/crt-gitam-batch-3/home?authuser=0)

# %% [markdown]
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDN3gVpKLcdy6UnH6fg2ekHc9ZdS8D7ahE95itBO7FAuXxZUfh&s)

# %% [markdown]
# - abd
# - def

# %%
print("HELLO WORLD !")
# Out:
# HELLO WORLD !

# %%
a=10.2
b=20
print(type(a),type(b))
# Out:
# <class 'float'> <class 'int'>

# %%
a = int(input("enter a value"))
b = int(input("enter b value"))
print(a+b)
# Out:
# enter a value10
# enter b value20
# 30

# %%
name = input("enter name")
age= int(input("enter age"))
print("my name is",name,end="")
print("my age is",age)
# Out:
# enter nameyaneefar
# enter age20
# my name is yaneefarmy age is 20

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               def                 if                  raise
# None                del                 import              return
# True                elif                in                  try
# and                 else                is                  while
# as                  except              lambda              with
# assert              finally             nonlocal            yield
# break               for                 not
# class               from                or
# continue            global              pass
